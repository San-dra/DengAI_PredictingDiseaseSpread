# %% [markdown]
# ## DengAI Predicting Disease Spread

# %%
# pip install pandas-profiling[notebook,html]
# pip install kmodes
# pip install --upgrade kmodes

# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display, Markdown
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
from kmodes.kmodes import KModes
from sklearn.model_selection import KFold
from sklearn.utils import resample ##
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import svm


from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: column;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     flex-direction: column;
# }
# </style>

# %% [markdown]
# ### 1. Loading Datasets

# %%
training_label = pd.read_csv("data/dengue_labels_train.csv")
training_features = pd.read_csv("data/dengue_features_train.csv")
test = pd.read_csv("data/dengue_features_test.csv")

training_label['id']=training_label['city'].astype(str) + training_label['year'].astype(str) + training_label['weekofyear'].astype(str) 
training_features['id']=training_features['city'].astype(str) + training_features['year'].astype(str) + training_features['weekofyear'].astype(str)
test['id']=test['city'].astype(str) + test['year'].astype(str) + test['weekofyear'].astype(str)

train = training_features.merge(training_label[['id','total_cases']], on = 'id')
test['total_cases']=-1
display(train.shape,test.shape)
display(train.head())
display(test.head())
# Out:
# (1456, 26)
# (416, 26)
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# ...

# %%
dataset=train.append(test)
display(dataset.shape)
display(dataset.head())
# Out:
# (1872, 26)
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# ...

# %% [markdown]
# ## 2. Data Profile

# %%
# profile = ProfileReport(train,title='DengAI Training Dataset Summary Report', html={'style':{'full_width':True}})
# profile.to_file(output_file="DengAI_DataProfile.html")

# %% [markdown]
# ### 2.1. Data Types

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1872 entries, 0 to 415
# Data columns (total 26 columns):
# city                                     1872 non-null object
# year                                     1872 non-null int64
# weekofyear                               1872 non-null int64
# week_start_date                          1872 non-null object
# ndvi_ne                                  1635 non-null float64
# ndvi_nw                                  1809 non-null float64
# ndvi_se                                  1849 non-null float64
# ndvi_sw                                  1849 non-null float64
# precipitation_amt_mm                     1857 non-null float64
# reanalysis_air_temp_k                    1860 non-null float64
# reanalysis_avg_temp_k                    1860 non-null float64
# reanalysis_dew_point_temp_k              1860 non-null float64
# reanalysis_max_air_temp_k                1860 non-null float64
# ...

# %%
dataset['week_start_date']=pd.to_datetime(dataset['week_start_date'])
dataset['week_day_name'] = dataset['week_start_date'].dt.day.astype('int')
dataset["month"] = dataset["week_start_date"].dt.month.astype('int')

# %%
#Changing datatypes from Objects to Categories.
for col in dataset:
    if dataset.dtypes[col].name == 'object':
        dataset[col] = dataset[col].astype('category')

# %% [markdown]
# Data Overview

# %%
# Missing Values
display(dataset.isna().sum()[dataset.isna().sum().ne(0)])
display(dataset.isin([0]).sum(axis=0)[dataset.isin([0]).sum(axis=0).ne(0)])
# Out:
# ndvi_ne                                  237
# ndvi_nw                                   63
# ndvi_se                                   23
# ndvi_sw                                   23
# precipitation_amt_mm                      15
# reanalysis_air_temp_k                     12
# reanalysis_avg_temp_k                     12
# reanalysis_dew_point_temp_k               12
# reanalysis_max_air_temp_k                 12
# reanalysis_min_air_temp_k                 12
# reanalysis_precip_amt_kg_per_m2           12
# reanalysis_relative_humidity_percent      12
# reanalysis_sat_precip_amt_mm              15
# reanalysis_specific_humidity_g_per_kg     12
# reanalysis_tdtr_k                         12
# station_avg_temp_c                        55
# station_diur_temp_rng_c                   55
# station_max_temp_c                        23
# station_min_temp_c                        23
# station_precip_mm                         27
# dtype: int64
# precipitation_amt_mm               296
# ...

# %%
#Duplicates
len(pd.DataFrame(dataset[dataset['id'].duplicated()]))
# Out:
# 0
